# %% [markdown]
# <a href="https://colab.research.google.com/github/pedroyepiz/PYTHON-2023-1/blob/main/3_mayo_2024.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random

# %%
def genreg():
    ap=["NUNEZ","CASTRO","'RUIZ","AVILA","ROJAS"]
    nomh=["PEDRO","RAUL","JUAN","ERNESTO","JOSE"]
    nomm=["KARELY","LUNA","MIA","MISTIKE","AZUL"]

    sexo=["HOMBRE","MUJER"]
    claves= []

    claves.append(random.choice(nomh))
    claves.append(random.choice(ap))
    claves.append(random.choice(ap))
    claves.append(random.choice(sexo))
    claves.append(random.randint(10,70))
    #dicc = dict(zip(llaves,claves))
    return tuple(claves)

# %%
lreg = []

# %%
llaves=["NOMBRE","APPAT","APMAT","SEXO","EDAD"]
claves=list(genreg())
reg = dict(zip(llaves,claves))
lreg.append(reg)
salida=pd.DataFrame(lreg)

# %%
import pandas as pd
salida=pd.DataFrame(lreg)

# %%
salida
# Out:
#     NOMBRE   APPAT  APMAT    SEXO  EDAD
# 0    PEDRO  CASTRO  AVILA  HOMBRE    47
# 1  ERNESTO   ROJAS  'RUIZ  HOMBRE    66
# 2     RAUL   'RUIZ  'RUIZ   MUJER    70
# 3    PEDRO   AVILA  NUNEZ  HOMBRE    23
# 4     JUAN   'RUIZ  NUNEZ   MUJER    31
# 5     JUAN   NUNEZ  AVILA  HOMBRE    60
